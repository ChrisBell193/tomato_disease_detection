# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/bigboiibell/code/personal/tomato_disease_detection'

# %%
os.listdir()
# Out:
# ['data', '.git', '.ipynb_checkpoints', 'tomato_disease_detection.ipynb']

# %%
base_path = os.path.join(os.getcwd(), 'data', 'train')
base_path
# Out:
# '/home/bigboiibell/code/personal/tomato_disease_detection/data/train'

# %%
folder_names = os.listdir(os.path.join(os.getcwd(), 'data', 'train'))
folder_names
# Out:
# ['Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Late_blight',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Bacterial_spot',
#  'Tomato___healthy',
#  'Tomato___Early_blight',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Target_Spot']

# %%
folder_names[0]
# Out:
# 'Tomato___Leaf_Mold'

# %%
image_files = [f for f in os.listdir(os.path.join(base_path, folder_names[0])) if f.endswith('.JPG')]

# %%
len(image_files)
# Out:
# 1000

# %%
image_file_paths = [os.path.join(base_path, folder_names[0], image_name) for image_name in image_files]

# %%
image = Image.open(image_file_paths[0])
plt.imshow(image)

# %%
train_file_paths = {}
base_path = os.path.join(os.getcwd(), 'data', 'train')
for folder_name in folder_names:
    image_files = [f for f in os.listdir(os.path.join(base_path, folder_name)) if f.endswith('.JPG')]
    train_file_paths[folder_name] = [os.path.join(base_path, folder_name, image_name) for image_name in image_files]
